# %%
import urllib.request  as urllib2 
from bs4 import BeautifulSoup

import json
from pandas.io.json import json_normalize

import pandas as pd

# %%
link = 'http://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2016/scores/pbp/0021600001_full_pbp.json'
page = urllib2.urlopen(link)
soup = BeautifulSoup(page)
data = soup.p.getText()
d = json.loads(data)
# Out:
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /home/ubuntu/anaconda3/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
json_normalize(d['g'])
# Out:
#              gcode         gid            mid  \
# 0  20161025/NYKCLE  0021600001  1483477945988
#
#                                                 next  \
# 0  http://data.nba.com/data/v2015/json/mobile_tea...
#
#                                                   pd
# 0  [{'pla': [{'hs': 0, 'opt1': 0, 'etype': 12, 'c...

# %%
df1 = json_normalize(d['g']['pd'])

# %%
json_normalize(d['g']['pd'])
# Out:
#    p                                                pla
# 0  1  [{'hs': 0, 'opt1': 0, 'etype': 12, 'cl': '12:0...
# 1  2  [{'hs': 28, 'opt1': 0, 'etype': 12, 'cl': '12:...
# 2  3  [{'hs': 48, 'opt1': 0, 'etype': 12, 'cl': '12:...
# 3  4  [{'hs': 82, 'opt1': 0, 'etype': 12, 'cl': '12:...

# %%
df1['pla'][0]
# Out:
# [{'cl': '12:00',
#   'de': 'Start Period',
#   'epid': '',
#   'etype': 12,
#   'evt': 0,
#   'hs': 0,
#   'locX': 0,
#   'locY': -80,
#   'mtype': 0,
#   'oftid': 0,
#   'opid': '',
#   'opt1': 0,
#   'opt2': 0,
#   'pid': 0,
#   'tid': 0,
#   'vs': 0},
#  {'cl': '12:00',
#   'de': 'Jump Ball Thompson vs Noah (Rose gains possession)',
#   'epid': '201565',
#   'etype': 10,
#   'evt': 1,
#   'hs': 0,
#   'locX': 0,
#   'locY': -80,
#   'mtype': 0,
#   'oftid': 1610612752,
#   'opid': '201149',
#   'opt1': 0,
#   'opt2': 0,
#   'pid': 202684,
#   'tid': 1610612739,
#   'vs': 0},
#  {'cl': '11:40',
#   'de': '[NYK 2-0] Rose Driving Layup Shot: Made (2 PTS) Assist: Noah (1 AST)',
#   'epid': '201149',
#   'etype': 1,
#   'evt': 2,
#   'hs': 0,
#   'locX': 4,
#   'locY': 8,
#   'mtype': 42,
#   'oftid': 1610612752,
#   'opid': '',
#   'opt1': 2,
#   'opt2': 0,
#   'pid': 201565,
#   'tid': 1610612752,
#   'vs': 2},
#  {'cl': '11:26',
#   'de': '[CLE] Love Hook Shot: Missed',
# ...

# %%
len(df1['pla'][0])
# Out:
# 134

# %%
df1['pla'][0][0]
# Out:
# {'cl': '12:00',
#  'de': 'Start Period',
#  'epid': '',
#  'etype': 12,
#  'evt': 0,
#  'hs': 0,
#  'locX': 0,
#  'locY': -80,
#  'mtype': 0,
#  'oftid': 0,
#  'opid': '',
#  'opt1': 0,
#  'opt2': 0,
#  'pid': 0,
#  'tid': 0,
#  'vs': 0}

# %%
type(df1['pla'][0][0])
# Out:
# dict

# %%
df = pd.DataFrame(df1['pla'][0])

# %%
df
# Out:
#           cl                                                 de     epid  \
# 0      12:00                                       Start Period
# 1      12:00  Jump Ball Thompson vs Noah (Rose gains possess...   201565
# 2      11:40  [NYK 2-0] Rose Driving Layup Shot: Made (2 PTS...   201149
# 3      11:26                       [CLE] Love Hook Shot: Missed
# 4      11:23                   [NYK] Noah Rebound (Off:0 Def:1)
# 5      11:16                    [NYK] Anthony Jump Shot: Missed
# 6      11:15              [NYK] Porzingis Rebound (Off:1 Def:0)
# 7      11:15   [NYK 4-0] Porzingis Tip Layup Shot: Made (2 PTS)
# 8      10:59  [CLE 2-4] James Jump Shot: Made (2 PTS) Assist...   202681
# 9      10:58  [NYK] Rose Turnover : Out of Bounds Lost Ball ...
# 10     10:46                      [CLE] Irving 3pt Shot: Missed
# 11     10:45                    [NYK] Lee Rebound (Off:0 Def:1)
# 12     10:34                        [NYK] Lee Jump Shot: Missed
# ...

# %%
null = None

# %%
a = {"resource":"boxscore","parameters":{"GameID":"0021601212","StartPeriod":1,"EndPeriod":10,"StartRange":0,"EndRange":28800,"RangeType":0},"resultSets":[{"name":"PlayerStats","headers":["GAME_ID","TEAM_ID","TEAM_ABBREVIATION","TEAM_CITY","PLAYER_ID","PLAYER_NAME","START_POSITION","COMMENT","MIN","FGM","FGA","FG_PCT","FG3M","FG3A","FG3_PCT","FTM","FTA","FT_PCT","OREB","DREB","REB","AST","STL","BLK","TO","PF","PTS","PLUS_MINUS"],"rowSet":[["0021601212",1610612766,"CHA","Charlotte",203077,"Michael Kidd-Gilchrist","F","","19:33",4,10,0.400,0,0,0.000,2,2,1.000,3,3,6,1,1,0,0,4,10,-9.000],["0021601212",1610612766,"CHA","Charlotte",101107,"Marvin Williams","F","","12:53",2,9,0.222,1,4,0.250,2,2,1.000,3,3,6,0,2,0,1,1,7,-5.000],["0021601212",1610612766,"CHA","Charlotte",203469,"Cody Zeller","C","","22:14",1,3,0.333,0,0,0.000,2,2,1.000,2,4,6,2,0,0,0,3,4,-9.000],["0021601212",1610612766,"CHA","Charlotte",201587,"Nicolas Batum","G","","10:04",0,3,0.000,0,1,0.000,0,0,0.000,0,1,1,4,1,0,0,0,0,-8.000],["0021601212",1610612766,"CHA","Charlotte",203148,"Brian Roberts","G","","28:09",2,7,0.286,0,3,0.000,0,0,0.000,0,1,1,1,1,0,3,0,4,-12.000],["0021601212",1610612766,"CHA","Charlotte",1626163,"Frank Kaminsky","","","25:01",3,11,0.273,0,3,0.000,0,1,0.000,0,1,1,2,0,0,1,1,6,-19.000],["0021601212",1610612766,"CHA","Charlotte",1627362,"Briante Weber","","","24:26",3,9,0.333,1,3,0.333,3,4,0.750,0,0,0,2,1,0,2,3,10,-17.000
5,0.400,0,2,0.000,0,0,0.000,1,1,2,1,1,0,0,0,4,2.000],["0021601212",1610612737,"ATL","Atlanta",2743,"Kris Humphries","","","10:32",1,4,0.250,1,2,0.500,2,2,1.000,2,2,4,0,3,0,1,0,5,2.000],["0021601212",1610612737,"ATL","Atlanta",1627098,"Malcolm Delaney","","","8:53",2,4,0.500,0,2,0.000,0,0,0.000,0,2,2,3,0,0,1,1,4,4.000]]},{"name":"TeamStats","headers":["GAME_ID","TEAM_ID","TEAM_NAME","TEAM_ABBREVIATION","TEAM_CITY","MIN","FGM","FGA","FG_PCT","FG3M","FG3A","FG3_PCT","FTM","FTA","FT_PCT","OREB","DREB","REB","AST","STL","BLK","TO","PF","PTS","PLUS_MINUS"],"rowSet":[["0021601212",1610612766,"Hornets","CHA","Charlotte","240:00",29,88,0.330,3,23,0.130,15,19,0.789,15,25,40,16,11,1,13,17,76,-27.000000],["0021601212",1610612737,"Hawks","ATL","Atlanta","240:00",41,79,0.519,7,27,0.259,14,18,0.778,11,39,50,30,6,4,16,17,103,27.000000]]},{"name":"TeamStarterBenchStats","headers":["GAME_ID","TEAM_ID","TEAM_NAME","TEAM_ABBREVIATION","TEAM_CITY","STARTERS_BENCH","MIN","FGM","FGA","FG_PCT","FG3M","FG3A","FG3_PCT","FTM","FTA","FT_PCT","OREB","DREB","REB","AST","STL","BLK","TO","PF","PTS"],"rowSet":[["0021601212",1610612766,"Hornets","CHA","Charlotte","Starters","92:53",9,32,0.281,1,8,0.125,6,6,1.000,8,12,20,8,5,0,4,8,25],["0021601212",1610612766,"Hornets","CHA","Charlotte","Bench","147:07",20,56,0.357,2,15,0.133,9,13,0.692,7,13,20,8,6,1,9,9,51],["0021601212",1610612737,"Hawks","ATL","Atlanta","Starters","117:22",22,38,0.579,1,7,0.143,9,12,0.750,4,24,28,14,2,1,10,8,54],["0021601212",1610612737,"Hawks","ATL","Atlanta","Bench","122:38",19,41,0.463,6,20,0.300,5,6,0.833,7,15,22,16,4,3,6,9,49]]}]}

# %%
df1 = pd.DataFrame(a['resultSets'][0]['rowSet'])

# %%
df1.columns = a['resultSets'][0]['headers']

# %%
df1
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0   0021601212  1610612766               CHA  Charlotte     203077
# 1   0021601212  1610612766               CHA  Charlotte     101107
# 2   0021601212  1610612766               CHA  Charlotte     203469
# 3   0021601212  1610612766               CHA  Charlotte     201587
# 4   0021601212  1610612766               CHA  Charlotte     203148
# 5   0021601212  1610612766               CHA  Charlotte    1626163
# 6   0021601212  1610612766               CHA  Charlotte    1627362
# 7   0021601212  1610612766               CHA  Charlotte     203101
# 8   0021601212  1610612766               CHA  Charlotte    1626203
# 9   0021601212  1610612766               CHA  Charlotte     203087
# 10  0021601212  1610612766               CHA  Charlotte    1626174
# 11  0021601212  1610612766               CHA  Charlotte     203948
# 12  0021601212  1610612766               CHA  Charlotte     202689
# ...

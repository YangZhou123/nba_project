# %%
import urllib.request  as urllib2 
from bs4 import BeautifulSoup
from dateutil.relativedelta import *
from dateutil.easter import *
from dateutil.rrule import *
from dateutil.parser import *
from datetime import *
import pandas as pd
import json

# %%
gid = '0021600991'

# %%
link0 = 'http://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2016/scores/gamedetail/%s_gamedetail.json' %gid
page0 = urllib2.urlopen(link0)
soup0 = BeautifulSoup(page0)
data0 = soup0.p.getText()
d = json.loads(data0)
link = 'http://popcornmachine.net/gf?date=%s&game=%s' % (d['g']['gcode'].split('/')[0],d['g']['gcode'].split('/')[1])
page = urllib2.urlopen(link)
soup = BeautifulSoup(page)
mytable = soup.find_all("div", attrs={"class":"topLeft text1"})
# Out:
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /home/ubuntu/anaconda3/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
for row in mytable:
    if (len(row.contents)) != 1:
        if (row.contents[2].split()[1]=='2') & (row.contents[2].split()[2]=='12:00'):
            print (row.contents[0].split(' Stint ')[0])
# Out:
# Cameron Payne
# Cristiano Felicio
# Denzel Valentine
# Nikola Mirotic
# Dwyane Wade
# Marvin Williams
# Marco Belinelli
# Frank Kaminsky III
# Treveon Graham
# Brian Roberts

# %%
startLineUp = [[],[],[],[]]
i=0
for row in mytable:
    try:
        print (row.a.contents[0])
        startLineUp[i].append(row.a.contents[0])
    except AttributeError:
        i = i+1
# Out:
# Kristaps Porzingis
# Carmelo Anthony
# Derrick Rose
# Courtney Lee
# Joakim Noah
# Justin Holiday
# Brandon Jennings
# Lance Thomas
# Kyle O'Quinn
# Willy Hernangomez
# Mindaugas Kuzminskas
# Ron Baker
# Sasha Vujacic
# Kristaps Porzingis
# Carmelo Anthony
# Derrick Rose
# Courtney Lee
# Joakim Noah
# Justin Holiday
# Brandon Jennings
# Lance Thomas
# Kyle O'Quinn
# Willy Hernangomez
# Mindaugas Kuzminskas
# Ron Baker
# Sasha Vujacic
# LeBron James
# Kyrie Irving
# J.R. Smith
# Kevin Love
# Tristan Thompson
# Richard Jefferson
# Mike Dunleavy
# Channing Frye
# Iman Shumpert
# DeAndre Liggins
# Jordan McRae
# Chris Andersen
# James Jones
# LeBron James
# Kyrie Irving
# J.R. Smith
# Kevin Love
# Tristan Thompson
# Richard Jefferson
# Mike Dunleavy
# Channing Frye
# Iman Shumpert
# DeAndre Liggins
# Jordan McRae
# Chris Andersen
# James Jones

# %%
startLineUp[1][:5]
# Out:
# ['Kristaps Porzingis',
#  'Carmelo Anthony',
#  'Derrick Rose',
#  'Courtney Lee',
#  'Joakim Noah']

# %%
startLineUp[2][:5]
# Out:
# ['LeBron James',
#  'Kyrie Irving',
#  'J.R. Smith',
#  'Kevin Love',
#  'Tristan Thompson']

# %%
startLineUp = [[],[],[],[]]
i=0
for row in mytable:
    try:
        print (row.a.contents[0])
        startLineUp[i].append(row.a.contents[0])
    except AttributeError:
        print ('=============')
        i = i+1
# Out:
# Kristaps Porzingis
# Carmelo Anthony
# Derrick Rose
# Courtney Lee
# Joakim Noah
# Justin Holiday
# Brandon Jennings
# Lance Thomas
# Kyle O'Quinn
# Willy Hernangomez
# Mindaugas Kuzminskas
# Ron Baker
# Sasha Vujacic
# ...
# Kristaps Porzingis
# Carmelo Anthony
# Derrick Rose
# Courtney Lee
# Joakim Noah
# Justin Holiday
# Brandon Jennings
# Lance Thomas
# Kyle O'Quinn
# Willy Hernangomez
# Mindaugas Kuzminskas
# Ron Baker
# Sasha Vujacic
# ...
# LeBron James
# Kyrie Irving
# J.R. Smith
# Kevin Love
# Tristan Thompson
# Richard Jefferson
# Mike Dunleavy
# Channing Frye
# Iman Shumpert
# DeAndre Liggins
# Jordan McRae
# Chris Andersen
# James Jones
# ...
# LeBron James
# Kyrie Irving
# J.R. Smith
# Kevin Love
# Tristan Thompson
# Richard Jefferson
# Mike Dunleavy
# Channing Frye
# Iman Shumpert
# DeAndre Liggins
# Jordan McRae
# Chris Andersen
# James Jones
# ...

# %%
mytable
# Out:
# [<th class="left " csk="Porzingis,Kristaps" data-append-csv="porzikr01" data-stat="player" scope="row"><a href="/players/p/porzikr01.html">Kristaps Porzingis</a></th>,
#  <th class="left " csk="Anthony,Carmelo" data-append-csv="anthoca01" data-stat="player" scope="row"><a href="/players/a/anthoca01.html">Carmelo Anthony</a></th>,
#  <th class="left " csk="Rose,Derrick" data-append-csv="rosede01" data-stat="player" scope="row"><a href="/players/r/rosede01.html">Derrick Rose</a></th>,
#  <th class="left " csk="Lee,Courtney" data-append-csv="leeco01" data-stat="player" scope="row"><a href="/players/l/leeco01.html">Courtney Lee</a></th>,
#  <th class="left " csk="Noah,Joakim" data-append-csv="noahjo01" data-stat="player" scope="row"><a href="/players/n/noahjo01.html">Joakim Noah</a></th>,
#  <th class="left " csk="Holiday,Justin" data-append-csv="holidju01" data-stat="player" scope="row"><a href="/players/h/holidju01.html">Justin Holiday</a></th>,
# ...

# %%
r_table=soup.findAll('th', data-stat="player")
# Out:
#   File "<ipython-input-94-42146324ffcd>", line 1
#     r_table=soup.findAll('th', data-stat="player")
#                               ^
# SyntaxError: keyword can't be an expression

# %%
#Generate lists
A=[]
B=[]
C=[]
D=[]
E=[]
F=[]
G=[]
for row in r_table.findAll("tr"):
    cells = row.findAll('td')
    states=row.findAll('th') #To store second column data
    if len(cells)==6: #Only extract table body not heading
        A.append(cells[0].find(text=True))
        B.append(states[0].find(text=True))
        C.append(cells[1].find(text=True))
        D.append(cells[2].find(text=True))
        E.append(cells[3].find(text=True))
        F.append(cells[4].find(text=True))
        G.append(cells[5].find(text=True))

# %%
startLineUp = []
for row in r_table.findAll("tr")[:5]:
    states=row.findAll('th')
    startLineUp.append((states[0].a.contents[0]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-74eab68739ac> in <module>()
#       1 startLineUp = []
# ----> 2 for row in r_table.findAll("tr")[:5]:
#       3     states=row.findAll('th')
#       4     startLineUp.append((states[0].a.contents[0]))
#
# AttributeError: 'ResultSet' object has no attribute 'findAll'

# %%
startLineUp
# Out:
# ['Kristaps Porzingis',
#  'Carmelo Anthony',
#  'Derrick Rose',
#  'Courtney Lee',
#  'Joakim Noah']

# %%
r_table[2]
# Out:
# <div class="overthrow table_container" id="div_box_cle_basic">
# <table class="sortable stats_table" data-cols-to-freeze="1" id="box_cle_basic"><caption>Cleveland Cavaliers (1-0) Table</caption>
# <colgroup><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col><col></col></colgroup>
# <thead>
# <tr class="over_header"><th></th>
# <th aria-label="" class=" over_header center" colspan="20" data-stat="header_tmp">Basic Box Score Stats</th>
# </tr>
# <tr>
# <th aria-label="Starters" class=" poptip sort_default_asc left" data-stat="player" scope="col">Starters</th>
# <th aria-label="Minutes Played" class=" poptip right" data-over-header="Basic Box Score Stats" data-stat="mp" data-tip="Minutes Played" scope="col">MP</th>
# ...

# %%
import csv

txt_file = r"1_Summary.txt"
csv_file = r"1_Summary.csv"

# use 'with' if the program isn't going to immediately terminate
# so you don't leave files open
# the 'b' is necessary on Windows
# it prevents \x1a, Ctrl-z, from ending the stream prematurely
# and also stops Python converting to / from different line terminators
# On other platforms, it has no effect
in_txt = csv.reader(open(txt_file, "rb"), delimiter = '\t')
out_csv = csv.writer(open(csv_file, 'wb'))

out_csv.writerows(in_txt)


def txtToCsv(filename):
    txt_file = r"%s.txt" %filename
    csv_file = r"%s.csv" %filename
    in_txt = csv.reader(open(txt_file, "rb"), delimiter = '\t')
    out_csv = csv.writer(open(csv_file, 'wb'))
    out_csv.writerows(in_txt)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-28ecbbc9c689> in <module>()
# ----> 1 r_table.findAll("tr")
#
# AttributeError: 'ResultSet' object has no attribute 'findAll'

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="no-js" data-root="/home/bbr/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">\n <head>\n  <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>\n  <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201708031" rel="dns-prefetch"/>\n  <link crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect"/>\n  <link crossorigin="" href="https://d9kjk42l7bfqz.cloudfront.net/req/201607120" rel="preconnect"/>\n  <link crossorigin="" href="https://www.google-analytics.com/" rel="preconnect"/>\n  <link crossorigin="" href="https://www.googletagservices.com" rel="preconnect"/>\n  <script class="allowed">\n   var sr_is_production = true;\nfunction vjs_ready(e){"loading"!=document.readyState?e():document.addEventListener("DOMContentLoaded",e)}var log_performance=!1,is_new_jscss_version=!1,sr_detect_operaMini=navigator.userAgent.indexOf("Opera Mini")>-1;if(sr_detect_operaM
# ...
